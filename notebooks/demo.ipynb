# %%
import pandas as pd

# read in csv file from data folder
df = pd.read_csv("data/horse-racing-sample.csv")

# show first 5 rows
df.head()
# Out:
#          Id      Course   RaceDate RaceTime                          Race
# 0  43903101  Cheltenham  13-Mar-20    13:30  JCB Triumph Hurdle (Grade 1)  \
# 1  43903101  Cheltenham  13-Mar-20    13:30  JCB Triumph Hurdle (Grade 1)
# 2  43903101  Cheltenham  13-Mar-20    13:30  JCB Triumph Hurdle (Grade 1)
# 3  43903101  Cheltenham  13-Mar-20    13:30  JCB Triumph Hurdle (Grade 1)
# 4  43903101  Cheltenham  13-Mar-20    13:30  JCB Triumph Hurdle (Grade 1)
#
#   Type  Class  AgeLimit   Prize  Ran  ... Stone  Lbs WeightLBS  Favs    Aid
# 0    h      1  4YO only  73,506   13  ...    10    7       147   NaN    NaN  \
# 1    h      1  4YO only  73,506   13  ...    11    0       154   NaN    NaN
# 2    h      1  4YO only  73,506   13  ...    11    0       154  2Fav  t   h
# 3    h      1  4YO only  73,506   13  ...    11    0       154   NaN    NaN
# 4    h      1  4YO only  73,506   13  ...    11    0       154   NaN      p
#
#          Trainer             Jockey Allow   OR
# ...
